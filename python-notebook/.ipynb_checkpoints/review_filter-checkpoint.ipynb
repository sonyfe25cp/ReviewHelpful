# %%
import os, sys
#Basic Data Statics
#Raw File Count is : 5838923

# %%
#Globle variables
file_path = '/data/opinion_spam/real/reviewsNew.txt'

# %%
#Filter useless reviews
datas = []
MIN_FD = 100
data_count = 0
meanful_data_count = 0
raw_file = open(file_path)
for line in raw_file:    
    try:
        line = line.decode('gbk')
    except:
        continue
    #print 'gbk', line
    line = line.encode('utf-8')
    #print 'utf8', line
    item = line.split('\t')
    data_count += 1
    if len(item) == 8:
        hfd = float(item[3])
        fd = float(item[4])
        ratings = float(item[5])
        if fd > MIN_FD:
            meanful_data_count += 1
            hfdfd = round(hfd/fd, 2)
            #whole_filted_body += item[7]
            item.append(hfdfd)
            datas.append(item)
raw_file.close()
print 'data count is :' + str(data_count)
print 'meanful data size : '+ str(meanful_data_count)
print datas[0]
# Out:
# data count is :5836532
# meanful data size : 19037
# ['A1004AX2J2HXGL', 'B00003CWPL', 'December 2, 2003', '111', '125', '5.0', '"But what the hell do they know, I said?"', ' If you\'re reading this, then you\'ve seen this movie or are at least curious what all the hype is about?    The late Stanley Kubrick, the only major filmmaker Lynch has cited as a direct cinematic influence, believed that ERASERHEAD was one of the most perfect "cinematic experiences" created to date.  This movie has enjoyed success on the midnight movie circuit for years, particularly in NYC where it ran almost every night for something like five years straight. I\'ve seen it on big and little screens in three different states.  Insofar as interpretations are concerned, I\'ve long since tossed all that out the window.  In terms of rational comprehension, ERASERHEAD is the fabled big fish that remains brilliantly elusive of any attempts to capture it.     This movie gets better, and more humorous, every time I watch it: in my opinion - ERASERHEAD is the cinematic experience that comes the closest to capturing "dream logic", next to the equally brilliant WAKING LIFE.  If you ever get the chance, watch ERASERHEAD in a movie theater with a great sound system - you will understand why Stanley Kubrick was moved enough to make his statement.  It\'s like experiencing someone else\'s dream - the ultimate act of voyeurism?  As if I was granted audience to a demonstration of delicate brain surgery, and catching glimpses of the patient\'s face throughout the operation (particularly the opening scene).  It creates such a visceral landscape with its dark, peculiar selections of image and sound, that it seems to be constantly reminding you that the "soul" is helplessly sloshing around somewhere inside an organic bag of blood, bone, hair follicles, industrial shrapnel, dirt piles and antique radiators; a terrifying and beautiful delineation of a living creature suddenly made aware of its own being (birth imagery abounding).  It is a perfect symphony of sound and image, amazing work for a first time feature film director!  I\'ve seen this movie placed in the HORROR section at local video stores; it\'s better suited for the COMEDY section, I fear.  The movie was created on the AFI campus in California; production beginning his last year there, and continuing on for several more years in secret.  Not for everyone, but certainly worth a peek.    I own a copy of ERASERHEAD on DVD, finally.  It is available at David Lynch\'s website for forty-five bucks plus shipping and handling.  Remastered sound and image, includes a few extras - the standout is a "stylized" interview with Lynch about the making of the film, the characters involved and anecdotes.    BTW - where is WILD AT HEART and LOST HIGHWAY for our DVD pleasure?     \n', 0.89]

# %%
#Transfer data into dataframe
import pandas as pd
col_names = ['rid', 'pid', 'date', 'hfd', 'fd', 'ratings', 'title', 'body', 'hfdfd']

df = pd.DataFrame(data = datas, columns = col_names)
#Relocate the data type
df[['hfd', 'fd','ratings']] = df[['hfd', 'fd', 'ratings']].astype(float)
#df['ratings'] = df['ratings'].astype(int)
print df.dtypes
df
# Out:
# rid         object
# pid         object
# date        object
# hfd        float64
# fd         float64
# ratings    float64
# title       object
# body        object
# hfdfd      float64
# dtype: object
#                   rid         pid                date  hfd   fd  ratings  \
# 0      A1004AX2J2HXGL  B00003CWPL    December 2, 2003  111  125        5
# 1      A103PHKSEPT10R  0939484463        July 5, 2000   69  116        5
# 2      A103U0Q3IKSXHE  0875845851    January 29, 2000  111  115        4
# 3      A105YVLAZNYQUU  B000634DCW       June 21, 2005    6  112        1
# 4      A1075MZNVRMSEO  1563249367       April 2, 2002  190  190        5
# 5      A108H0RI2LWLUO  B00004WHIL     August 22, 2000  177  181        3
# 6      A10DE6RF8970ET  B0007XHLZM        May 22, 2005  133  137        4
# 7      A10ETSMF2H8QG2  B000056JBO       April 7, 2002  108  113        5
# 8      A10EW5N83RTO27  0195102797       April 6, 2000   98  158        4
# 9      A10EW5N83RTO27  0060738170   December 14, 2005   67  152        5
# 10     A10FBJXMQPI0LL  0683307711    January 24, 2001  121  122        5
# 11     A10FBJXMQPI0LL  0789451247   December 23, 2000  104  107        4
# 12     A10IJF7UD9I86G  B00004TMRB   November 18, 2002   96  108        5
# 13     A10IJF7UD9I86G  B0000696CZ  September 12, 2002  607  649        5
# 14     A10KKJMBY5L7TK  0517265745       March 3, 2001  115  115        5
# 15     A10KKJMBY5L7TK  0345425871    January 21, 2001  105  121        2
# 16     A10KQMJINSG777  1559391766       June 17, 2002   96  103        5
# 17     A10NJX8AI9IRU9  0310205719       March 4, 2004   54  177        1
# 18     A10P0BX64HLW7H  B00000G20L       March 1, 2000  313  318        4
# 19     A10PDEWA7CDG99  B0001611DS    October 12, 2004  223  226        5
# 20     A10RJ73FK600DJ  0684869128      March 12, 2001  120  149        5
# 21     A10RJ73FK600DJ  0226493644     October 9, 2000   39  112        1
# 22     A10RJ73FK600DJ  0830813241  September 23, 1998  100  182        1
# 23     A10UA219PG4Q74  0740703579      April 29, 2000    6  113        3
# 24     A10WOHX7AOZ8MU  B000255LKW        July 3, 2005   79  125        1
# 25     A10XJR7CWHNKWU  B000006TRV    October 30, 2002  398  410        5
# 26     A10YR68JAOWZH8  B0000C3I2X   November 14, 2003  137  140        5
# 27     A11046XQ40ND5H  B00005JKFR        May 29, 2003  195  197        5
# 28     A110SXBC1UMFZA  B00008DDVV      March 20, 2003   93  317        1
# 29     A111AUAVWX6YIQ  0007142951       March 4, 2003  102  106        5
# ...               ...         ...                 ...  ...  ...      ...
# 19007  A2E6R5BLTF0ESS  081353433X  September 16, 2004   28  115        5
# 19008  A2FUF0I57ZS5OC  0060784156    October 13, 2004   40  157        1
# 19009  A2P8JWQ21KDFGS  B00008DDVV      August 5, 2003  128  511        1
# 19010  A2RTJK4YY7TW70  0910019665   September 4, 2002   28  119        1
# 19011  A2TYY6O7503Z9G  0964398818   December 25, 2002   42  136        1
# 19012  A328VA2ABDO2VN  0387987010   February 14, 2000   39  106        2
# 19013  A33UYW6UVC86TO  0966034619       March 6, 2001   25  121        2
# 19014  A365PEO6XKI2PZ  0275957896   December 23, 1999   12  116        1
# 19015  A371WEI52AAFWG  1400053668      March 30, 2004   31  113        1
# 19016  A39AV02FXSGQRT  0465044255   December 13, 2001   14  174        2
# 19017  A3A67BB8KSFODU  1591020840   December 23, 2003   60  140        5
# 19018  A3DECSKSCHP8HK  0740703579       April 3, 2000   24  335        1
# 19019  A3K0K5IAL4R7OX  074353638X       April 6, 2004  132  898        1
# 19020  A3MI7TF9DVXU8K  0764560794   February 28, 2001   11  110        4
# 19021  A3OAKTRKBE11SE  081353433X     October 2, 2004   32  118        5
# 19022  A3U3DWRTNIUORR  0465068359       July 18, 2001   22  121        5
# 19023  A3U6GW8DR16FFJ  1883219027      April 12, 2000   10  145        1
# 19024  A3UM9WAXSJVG9E  0465037712      March 16, 2002   10  143        2
# 19025  A3W31INS561T8P  0385509510       July 19, 2003   25  102        1
# 19026   A8T7IWCVKV70U  0740703579   February 27, 2000   68  306        1
# 19027   ACGZCJ3TSL3X6  0740703579       March 2, 2000   17  220        2
# 19028   ACRZXRDVYKLG2  B0002V7SMA     October 8, 2004    8  123        1
# 19029   AD4BMXOP0PNJH  B0002HDXTQ       July 13, 2004   11  147        1
# 19030   AJ3UPR1QLF2DM  0140277447   November 12, 2004   95  208        5
# 19031   AN5W0H0L1AX0M  0740703579      March 11, 2000   11  169        2
# 19032   AOSD599UOBIN9  0740703579      April 12, 2000   10  160        2
# 19033   APZXUXI1XPZW6  0671015206   December 19, 2002   18  174        2
# 19034   ASTD6SVB36GD6  1400053668       April 4, 2004   30  128        1
# 19035   ASUYYY0H9IUAE  0740703579       March 2, 2000   94  337        3
# 19036   AU9LFLW14QNPY  0805073396       July 11, 2004   30  106        3
#
#                                                    title  \
# 0              "But what the hell do they know, I said?"
# 1                     Credible, Interesting, & Devasting
# 2                  Identifying the horns of the dilemma.
# 3                                                 UGGHHH
# 4      A historical portrait & revelation- un chin de...
# 5          nice unit, but wireless is expensive and slow
# 6      A little more, and a little smaller than the o...
# 7                                             Great Buy!
# 8                a necessary challenge to fundamentalism
# 9      If people would only take biblical scholarship...
# 10                The ultimate in drug-free pain relief!
# 11     Great book!  Well written with GREAT pix, BUT....
# 12     like the PSX before it, it is home of the best...
# 13                     Some major improvements over GTA3
# 14                                Every Word has a Story
# 15                          Overstated Thesis, Dry Book.
# 16                   Great Book from a Wonderful Teacher
# 17                 American Consumer Driven Gospel Light
# 18     A good enough replacement for 35mm point-and-s...
# 19                                    Best Yoga DVD Ever
# 20                              Scholarly and Accessible
# 21     Poor Research Cannot Be A Basis For Policy Cha...
# 22                                 Slick and Superficial
# 23                                  Some great ideas....
# 24                                                   Ugh
# 25                         Inside The Floyd's Rock Opera
# 26                                 Nice piece of history
# 27      Remember back when nothing "happened" in movies?
# 28                         A gifted filmmaker of fiction
# 29                          A tease becomes a revelation
# ...                                                  ...
# 19007                              Just The Facts, Ma'am
# 19008                                          Oh Please
# 19009                                       mockumentary
# 19010             The Ron Popiel of real estate books...
# 19011                     A scientific fact is not true.
# 19012                                      Let's Pretend
# 19013    Was recommended by Veganmom and it is not Vegan
# 19014                                   Outdated Science
# 19015                               Flipside of the coin
# 19016                                An article of faith
# 19017                 Unconventional but very successful
# 19018                               A big Disappiontment
# 19019                               A Creditably Problem
# 19020                  SUPPORT  USA      (SAFE PRACTICE)
# 19021                     This is one of the best books
# 19022                      A shocking and important book
# 19023                            7 Habits, Zero Insights
# 19024                            Basic Premise Is Flawed
# 19025  For anyone interested in a factual, well writt...
# 19026         Sorry, this book is flawed in the analysis
# 19027                                      Disappointing
# 19028                                    Enough Already!
# 19029  Another Fahrenheit 9-11, we all see what we wa...
# 19030                        It is time to honor history
# 19031                                              Ditto
# 19032                        statistical, boring and dry
# 19033                                 not so much fun...
# 19034                                        Distraction
# 19035                 Not "The Millionaire Next Door II"
# 19036                              rageagainst the right
#
#                                                     body  hfdfd
# 0       If you're reading this, then you've seen this...   0.89
# 1       I've read Prof Butz's book twice and an still...   0.59
# 2       Prior to reading this book, I chalked up the ...   0.97
# 3       Craptacular and boring. The cinematography an...   0.05
# 4       This book is a fascinating journey through th...   1.00
# 5       If you can afford the...wireless, and realize...   0.98
# 6       6/4/05 - Addendum There's no backlight on the...   0.97
# 7       Even though this is one of the cheaper matres...   0.96
# 8       Ehrman is doing for the New Testament what sc...   0.62
# 9       I just emailed Prof. Ehrman that had I been a...   0.44
# 10      As a Clinical Massage Therapist at a hospital...   0.99
# 11      FIRST, A WORD ON HEALTH CARE PUBLICATIONS- Wh...   0.97
# 12      Purchased a PS2 a little over a year ago for ...   0.89
# 13      There are many enhancements over GTA3. Here i...   0.94
# 14      A lot of hard work and passion went into this...   1.00
# 15      This books say it can show you "how to unders...   0.87
# 16      Before I begin, I must admit limited objectiv...   0.93
# 17      As a pastor, I really struggle with the growi...   0.31
# 18      My review will focus on how well the 370z rep...   0.98
# 19      I officially renounce all my previous five st...   0.99
# 20      In "The Bible Unearthed," Israel Finkelstein ...   0.81
# 21      John Lott's provocatively titled "More Guns: ...   0.35
# 22      Phillip Johnson is a law professor at UC Berk...   0.55
# 23      This text offered some great insight in to ho...   0.05
# 24      To show example of Hawthorne Heights's main a...   0.63
# 25      "The Wall," Pink Floyd's 1979 concept album a...   0.97
# 26      This 2 disc set provides a most wonderful gli...   0.98
# 27      Watching this recently, it amazed me how litt...   0.99
# 28      While Moore may be a complete and utter idiot...   0.29
# 29      In what turned out to be a colossal tease, La...   0.96
# ...                                                  ...    ...
# 19007   The engineered rage of creationists and other...   0.24
# 19008   Umm lets see it's about Bill cheating and his...   0.25
# 19009   if this is what hollywood considers an award ...   0.25
# 19010   This book is very poorly written. The author ...   0.24
# 19011   On the bottom of page 19, Valerie Hunt says: ...   0.31
# 19012   I am somewhat concerned about the authors' mo...   0.37
# 19013   I was a little disappointed to find out this ...   0.21
# 19014   Have you ever heard of the Pygmalion Effect, ...   0.10
# 19015   I find this kind of propaganda rather obnoxio...   0.27
# 19016   I looked to this book to present for me the b...   0.08
# 19017   A new player seems to have appeared on the fi...   0.43
# 19018   I read Stanley's first book, The Millionaire ...   0.07
# 19019   Interveiwed by the Washington Post, Jan 23 19...   0.15
# 19020   The lay out is very colorfull. As this is my ...   0.10
# 19021   This is one of the best books about the newes...   0.27
# 19022   Iris Chang has done a great service to the ca...   0.18
# 19023   Most overrated book of the decade.  Surely it...   0.07
# 19024   ( This is a corrected version of the review I...   0.07
# 19025   For anyone interested in a factual, well writ...   0.25
# 19026   Dr. Stanley, you disappointed me.  Amazon.com...   0.22
# 19027   The negatives other reviewers (e. g., bombadi...   0.08
# 19028   My God! It is amazing to see how far the left...   0.07
# 19029   Yes, please buy this DVD and hope it makes to...   0.07
# 19030   When someone mentions the word holocaust, mos...   0.46
# 19031   Dr.Stanley used this sequel to line his milli...   0.07
# 19032   I bought this book only because his first one...   0.06
# 19033   I was given this book as a gift and was thoro...   0.10
# 19034   This is an obvious attempt at distracting the...   0.23
# 19035   Like most of the other reviewers, I have read...   0.28
# 19036   Losers in political battles typically come up...   0.28
#
# [19037 rows x 9 columns]

# %%
#State the hfd/fd and ratings
#ratings
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import seaborn as sns
ratings_range = range(1, 6)
g = sns.factorplot(x = 'ratings', data=df, kind='count', palette='BuPu', size=5, aspect=1.5, 
                   order=ratings_range)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
import matplotlib
print 'matplotlib.get_backend(): ' + matplotlib.get_backend()
# Out:
# matplotlib.get_backend(): module://ipykernel.pylab.backend_inline

# %%
#show the hfd/fd distribution

#add new column to df
#df['hfd/fd'] = (round(df['hfd']/df['fd'], 2)).astype(float)
#df['hfd/fd'] = (df['hfd'] * 100 /df['fd']).astype(float)
#df['hfd/fd'] = (df['hfd/fd']).astype(int)
#df['hfd/fd'] = (df['hfd/fd']/100).astype(float)
#df
#new_df = df[df["fd"] > 10]
#new_df

# %%
import numpy as np
hfd_range = np.arange(0, 1.1, step=0.1)

g = sns.factorplot(x = 'hfdfd', data=df, kind='count', palette='BuPu', size=5, aspect=1.5, order=hfd_range, row_order=hfd_range)

# %%
#Transfer into label with body
tdf = df[['hfdfd', 'body']]
print tdf.dtypes
tdf
# Out:
# hfdfd    float64
# body      object
# dtype: object
#        hfdfd                                               body
# 0       0.89   If you're reading this, then you've seen this...
# 1       0.59   I've read Prof Butz's book twice and an still...
# 2       0.97   Prior to reading this book, I chalked up the ...
# 3       0.05   Craptacular and boring. The cinematography an...
# 4       1.00   This book is a fascinating journey through th...
# 5       0.98   If you can afford the...wireless, and realize...
# 6       0.97   6/4/05 - Addendum There's no backlight on the...
# 7       0.96   Even though this is one of the cheaper matres...
# 8       0.62   Ehrman is doing for the New Testament what sc...
# 9       0.44   I just emailed Prof. Ehrman that had I been a...
# 10      0.99   As a Clinical Massage Therapist at a hospital...
# 11      0.97   FIRST, A WORD ON HEALTH CARE PUBLICATIONS- Wh...
# 12      0.89   Purchased a PS2 a little over a year ago for ...
# 13      0.94   There are many enhancements over GTA3. Here i...
# 14      1.00   A lot of hard work and passion went into this...
# 15      0.87   This books say it can show you "how to unders...
# 16      0.93   Before I begin, I must admit limited objectiv...
# 17      0.31   As a pastor, I really struggle with the growi...
# 18      0.98   My review will focus on how well the 370z rep...
# 19      0.99   I officially renounce all my previous five st...
# 20      0.81   In "The Bible Unearthed," Israel Finkelstein ...
# 21      0.35   John Lott's provocatively titled "More Guns: ...
# 22      0.55   Phillip Johnson is a law professor at UC Berk...
# 23      0.05   This text offered some great insight in to ho...
# 24      0.63   To show example of Hawthorne Heights's main a...
# 25      0.97   "The Wall," Pink Floyd's 1979 concept album a...
# 26      0.98   This 2 disc set provides a most wonderful gli...
# 27      0.99   Watching this recently, it amazed me how litt...
# 28      0.29   While Moore may be a complete and utter idiot...
# 29      0.96   In what turned out to be a colossal tease, La...
# ...      ...                                                ...
# 19007   0.24   The engineered rage of creationists and other...
# 19008   0.25   Umm lets see it's about Bill cheating and his...
# 19009   0.25   if this is what hollywood considers an award ...
# 19010   0.24   This book is very poorly written. The author ...
# 19011   0.31   On the bottom of page 19, Valerie Hunt says: ...
# 19012   0.37   I am somewhat concerned about the authors' mo...
# 19013   0.21   I was a little disappointed to find out this ...
# 19014   0.10   Have you ever heard of the Pygmalion Effect, ...
# 19015   0.27   I find this kind of propaganda rather obnoxio...
# 19016   0.08   I looked to this book to present for me the b...
# 19017   0.43   A new player seems to have appeared on the fi...
# 19018   0.07   I read Stanley's first book, The Millionaire ...
# 19019   0.15   Interveiwed by the Washington Post, Jan 23 19...
# 19020   0.10   The lay out is very colorfull. As this is my ...
# 19021   0.27   This is one of the best books about the newes...
# 19022   0.18   Iris Chang has done a great service to the ca...
# 19023   0.07   Most overrated book of the decade.  Surely it...
# 19024   0.07   ( This is a corrected version of the review I...
# 19025   0.25   For anyone interested in a factual, well writ...
# 19026   0.22   Dr. Stanley, you disappointed me.  Amazon.com...
# 19027   0.08   The negatives other reviewers (e. g., bombadi...
# 19028   0.07   My God! It is amazing to see how far the left...
# 19029   0.07   Yes, please buy this DVD and hope it makes to...
# 19030   0.46   When someone mentions the word holocaust, mos...
# 19031   0.07   Dr.Stanley used this sequel to line his milli...
# 19032   0.06   I bought this book only because his first one...
# 19033   0.10   I was given this book as a gift and was thoro...
# 19034   0.23   This is an obvious attempt at distracting the...
# 19035   0.28   Like most of the other reviewers, I have read...
# 19036   0.28   Losers in political battles typically come up...
#
# [19037 rows x 2 columns]

# %%
#Fit TFIDF model
import nltk
import re
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("english")

#去掉标点符号
def tokenize_and_stem(text):
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered = []
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered.append(token)
    stems = []
    for t in filtered:
        tt = stemmer.stem(t)
        if tt not in stems:
            stems.append(tt)
    return stems

test_str = 'I haved two dreams.'
print type(test_str)


tokenize_and_stem(test_str)
# Out:
# <type 'str'>
# ['i', u'have', u'two', u'dream']

# %%
import codecs
#print 'whole_filted_body:'+ str(len(whole_filted_body))

#how to save file with utf-8
#Save the text file to disk and analysis error
#_outfile = codecs.open('/tmp/_outfile_whole_filted_body', 'w', 'utf-8')
#_outfile.write(whole_filted_body)
#_outfile.close
#print 'output file over'

#whole_filted_body = filter_non_English(whole_filted_body)
#english_only = ''.join(x for x in whole_filted_body if ord(x) < 256)

#print 'filted non english characters, whole body : ', str(len(english_only))
#print blist

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


#tfidf = TfidfVectorizer(max_df=0.5, max_features=200000,
#                        min_df=1, stop_words='english',
#                        tokenizer=tokenize_and_stem, ngram_range=(1, 1))

tfidf = TfidfVectorizer(max_df=0.8, max_features=100000,
                        min_df=0.05, stop_words='english',
                        tokenizer=tokenize_and_stem, ngram_range=(1, 1))
print tfidf

#########################
blist = []

for bbb in tdf.body:
    xxx = ''.join(x for x in bbb if ord(x) < 128)
    blist.append(xxx)
print type(blist)
#########################

print 'length: ', len(blist)

#blist = ['haha, i am in beijing', 'hoho, i am in shanghai', 'haha', 'hoho', 'beijing is great']
print type(blist)

tfidf_mat = tfidf.fit_transform(blist)

print tfidf_mat.shape
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=0.8, max_features=100000, min_df=0.05,
#         ngram_range=(1, 1), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=<function tokenize_and_stem at 0x7fd34bc84320>,
#         use_idf=True, vocabulary=None)
# <type 'list'>
# length:  19037
# <type 'list'>
# (19037, 437)

# %%
# dunnscore的评估函数，输入点集的矩阵表示vectors、已经分好类的标记tag
# 输出评分值
def dunnscore(vectors, tag):
    ncluster = max(tag) + 1
    clusters = [[] for x in range(ncluster)]
    #将输入的稀疏矩阵转化为紧密矩阵
    vectors = vectors.todense()
    for i in range(0, vectors.shape[0]):
        clusters[tag[i]].append(vectors[i])
    #聚类中心
    cent = []
    for a in clusters:
        cent.append(np.mean(a, axis=0))
    #各个簇的直径
    diam = []

    for a in clusters:
        big = []
        for i in range(0, len(a)):
            for j in range(0, len(a)):
                big.append(distance.euclidean(a[i], a[j]))
        diam.append(max(big))

    cross = []
    for i in range(ncluster):
        for j in range(i + 1, ncluster):
            cross.append(distance.euclidean(cent[i], cent[j]))
    return min(cross) / max(diam)

#davies boulding的评分值
#输入、输出同上
def davies(vectors, tag):
    ncluster = max(tag) + 1
    clusters = [[] for x in range(ncluster)]
    vectors = vectors.todense()
    for i in range(vectors.shape[0]):
        clusters[tag[i]].append(vectors[i])
    cent = []

    for a in clusters:
        cent.append(np.mean(a, axis=0))

    diam = []
    for c in clusters:
        tp = []
        for node1 in c:
            for node2 in c:
                tp.append(distance.euclidean(node1, node2))
        diam.append(max(tp))

    for a in clusters:
        tp = []
        for node1 in c:
            for node2 in c:
                tp.append(distance.euclidean(node1, node2))
    cros = []

    res = 0
    for i in range(ncluster):
        tp = []
        for j in range(ncluster):
            if i == j:
                continue
            tp.append((diam[i] + diam[j]) / (distance.euclidean(cent[i], cent[j])))
        res += max(tp)
    return res / ncluster

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial import distance
##KMeans
for i in range(2, 20):
    km = KMeans(i)
    #调用聚类函数聚类，得到一个打好标签的labels
    km.fit(tfidf_mat)
    tag = km.labels_.tolist()
    #silhouette评分是系统自带的

    print "k = ",i, "runs : ", "dunnscore", dunnscore(tfidf_mat, tag), "davies", davies(tfidf_mat, tag), "silhouette", metrics.silhouette_score(
        tfidf_mat, km.labels_, metric="euclidean")
    #print("Silhouette Coefficient: %0.3f"
     # % metrics.silhouette_score(tfidf_mat, km.labels_, sample_size=50))
