# %%
# %matplotlib inline
import numpy as np
import sys
import pandas as pd
import matplotlib.pyplot as plt
print sys.version
print "pandas.version:", pd.__version__
# Out:
# 2.7.6 (default, Mar 22 2014, 22:59:56)
# [GCC 4.8.2]
# pandas.version: 0.17.1

# %%
from pandas.io import data

# %% [markdown]
# * Yahoo Data
# * Google Data

# %%
# ?pandas.io.data

# %%
pandas.io.data
# Out:
# <module 'pandas.io.data' from '/usr/local/lib/python2.7/dist-packages/pandas/io/data.pyc'>

# %%
start = pd.to_datetime('2011-1-1')
end = pd.to_datetime('2015-1-1')

# %%
ticker_symbols = ['WTI','CHK', 'TSLA', 'CBAK']#OIL PRODUCER + battery

# %%
wti = data.get_data_yahoo(ticker_symbols[0], start=start, end=end)

# %%
wti.head()
# Out:
#                  Open       High        Low      Close   Volume  Adj Close
# Date
# 2011-01-03  18.100000  18.430000  17.930000  18.320000   883600  15.483066
# 2011-01-04  18.480000  18.590000  17.940001  18.040001  1171000  15.246426
# 2011-01-05  17.950001  18.410000  17.510000  18.250000   644200  15.423906
# 2011-01-06  18.360001  18.430000  17.799999  17.910000   762700  15.136556
# 2011-01-07  18.010000  18.120001  17.700001  18.040001   695000  15.246426

# %%
for symbol in ticker_symbols:
    print symbol
# Out:
# WTI
# CHK
# TSLA
# CBAK

# %%
pan1 = data.get_data_yahoo(ticker_symbols, start = start, end = end)

# %%
pan1

# %%
type(pan1)

# %%
pan1.shape

# %%
pan1.Open.head()

# %%
pan1.major_xs('2013-5-1')
# Out:
#            Open       High    Low      Close    Volume  Adj Close
# CBAK   0.620000   0.790000   0.60   0.770000     56800   0.770000
# CHK   19.900002  19.979996  18.86  19.190006  17267300  17.569929
# TSLA  55.990002  55.990002  53.00  53.279999   2742800  53.279999
# WTI   11.540000  11.540000  11.03  11.220000    720500  10.394898

# %%
pan1.minor_xss('CHK').head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2011-01-03  26.390004  26.650004  26.209997  26.510004  12056500  23.426016
# 2011-01-04  26.690001  26.690001  25.929998  26.219995  10305300  23.169744
# 2011-01-05  26.140002  26.589998  26.030001  26.500005   8764600  23.417180
# 2011-01-06  26.800004  27.360003  26.599998  26.670004  17401300  23.567402
# 2011-01-07  26.710000  27.019997  26.629995  26.950003  10458000  23.814828

# %%
pan1.mean()
# Out:
#            Open       High        Low      Close           Volume  Adj Close
# CBAK   1.656451   1.732018   1.595865   1.654354    110536.978131   3.470020
# CHK   24.397625  24.743858  24.002088  24.369186  14150370.874751  22.285542
# TSLA  96.593976  98.505407  94.558519  96.555656   4466960.834990  96.555656
# WTI   17.379592  17.742485  16.988211  17.362227    797623.161034  15.707380

# %%
df = pan1.to_frame()

# %%
df.index.levels
# Out:
# FrozenList([[2011-01-03 00:00:00, 2011-01-04 00:00:00, 2011-01-05 00:00:00, 2011-01-06 00:00:00, 2011-01-07 00:00:00, 2011-01-10 00:00:00, 2011-01-11 00:00:00, 2011-01-12 00:00:00, 2011-01-13 00:00:00, 2011-01-14 00:00:00, 2011-01-18 00:00:00, 2011-01-19 00:00:00, 2011-01-20 00:00:00, 2011-01-21 00:00:00, 2011-01-24 00:00:00, 2011-01-25 00:00:00, 2011-01-26 00:00:00, 2011-01-27 00:00:00, 2011-01-28 00:00:00, 2011-01-31 00:00:00, 2011-02-01 00:00:00, 2011-02-02 00:00:00, 2011-02-03 00:00:00, 2011-02-04 00:00:00, 2011-02-07 00:00:00, 2011-02-08 00:00:00, 2011-02-09 00:00:00, 2011-02-10 00:00:00, 2011-02-11 00:00:00, 2011-02-14 00:00:00, 2011-02-15 00:00:00, 2011-02-16 00:00:00, 2011-02-17 00:00:00, 2011-02-18 00:00:00, 2011-02-22 00:00:00, 2011-02-23 00:00:00, 2011-02-24 00:00:00, 2011-02-25 00:00:00, 2011-02-28 00:00:00, 2011-03-01 00:00:00, 2011-03-02 00:00:00, 2011-03-03 00:00:00, 2011-03-04 00:00:00, 2011-03-07 00:00:00, 2011-03-08 00:00:00, 2011-03-09 00:00:00, 2011-03-10 00:00:00
# ...

# %%
df.reset_index()
# Out:
#            Date minor        Open        High         Low       Close  \
# 0    2011-01-03  CBAK    1.940000    1.990000    1.940000    1.960000
# 1    2011-01-03   CHK   26.390004   26.650004   26.209997   26.510004
# 2    2011-01-03  TSLA   26.840000   27.000000   25.900000   26.620001
# 3    2011-01-03   WTI   18.100000   18.430000   17.930000   18.320000
# 4    2011-01-04  CBAK    1.980000    2.070000    1.980000    2.020000
# 5    2011-01-04   CHK   26.690001   26.690001   25.929998   26.219995
# 6    2011-01-04  TSLA   26.660000   26.950001   26.020000   26.670000
# 7    2011-01-04   WTI   18.480000   18.590000   17.940001   18.040001
# 8    2011-01-05  CBAK    2.060000    2.060000    1.930000    1.950000
# 9    2011-01-05   CHK   26.140002   26.589998   26.030001   26.500005
# 10   2011-01-05  TSLA   26.480000   26.900000   26.190001   26.830000
# 11   2011-01-05   WTI   17.950001   18.410000   17.510000   18.250000
# ...
