# %%
a ='1'
a
# Out:
# '1'

# %%
import numpy as np
np.__version__
# Out:
# '1.9.2'

# %%
import pandas as pd
pd.__version__
# Out:
# u'0.17.1'

# %%
import matplotlib 
matplotlib.__version__
# Out:
# '1.5.0'

# %%
import sys
print sys.version
# Out:
# 2.7.6 (default, Mar 22 2014, 22:59:56)
# [GCC 4.8.2]

# %%
import pyhdfs
#fs = pyhdfs.connect("192.168.1.107", 9000)

# %%
12 * 1024 / 80.0
# Out:
# 153.6

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.plot(range(20), range(20))

ist = [[1,4],[2,1],[3,1]]
plt.plot(ist)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbef1e7ff90>,
#  <matplotlib.lines.Line2D at 0x7fbef1e0e190>]

# %%
import seaborn as sns
def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
sinplot()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris)
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
x = np.random.normal(size=100)
x
# Out:
# array([-2.66988527, -1.76920162, -2.25818535, -0.23946746, -1.13817386,
#         0.37497466,  0.17173716,  0.53691533,  0.97043375,  0.17934294,
#         0.13783519, -0.37802347, -0.07320181, -0.16107772, -0.1455951 ,
#         0.46478747, -0.45519984,  1.4827537 , -1.59517462,  0.41653304,
#        -0.18724517, -1.620494  ,  2.13270296, -1.17754906,  0.99306625,
#         0.23046686, -0.499183  , -2.51020341, -2.1787025 ,  0.47000048,
#         0.25059206, -0.30123161,  0.50786637, -0.03337792,  1.43069116,
#         0.38517588, -0.67490878, -0.04293403, -0.36912466, -2.3521669 ,
#         1.28258103,  0.68253883, -1.58347099, -0.43446111, -0.69597781,
#         0.65353115, -1.7037609 , -1.01399088, -0.13526817,  0.1492038 ,
#        -0.2258052 ,  0.83124312,  1.32190199, -0.60541891,  0.05156388,
#        -1.00946543, -0.61877733,  0.04847548, -1.14529818,  0.39623919,
#        -0.27136021,  1.78258437,  0.33808842,  0.4079476 , -2.64206938,
#         1.40991446,  0.51730987,  1.87838916, -0.08923538, -0.59392432,
#         0.06716693, -0.33702639,  0.60810485, -1.55781385,  1.18406686,
#        -0.20051336, -0.20738043, -0.55099153,  1.3392322 , -0.14594913,
#         1.10605533,  0.85110444, -2.03398071,  0.61628229,  0.03252412,
#         0.02991875, -0.02798367, -0.77619045, -0.55281555, -0.05711493,
#        -3.38715258, -0.2937173 ,  0.24357986, -0.28990254, -0.81627734,
#        -0.01307427,  0.83440697, -0.9139992 , -1.27063691, -0.29497484])

# %%
sns.distplot(x, kde=False, rug=False)

# %%
sns.distplot(x)

# %%
import nltk
print nltk.__version__
# Out:
# 3.1
